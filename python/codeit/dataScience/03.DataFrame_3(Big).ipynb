# %%
import pandas as pd

# %%
b_df = pd.read_csv('data/laptops.csv')
b_df
# Out:
#      brand             model  ram hd_type  hd_size  screen_size   price  \
# 0     Dell  Inspiron 15-3567    4     hdd     1024         15.6   40000
# 1    Apple       MacBook Air    8     ssd      128         13.3   55499
# 2    Apple       MacBook Air    8     ssd      256         13.3   71500
# 3    Apple       MacBook Pro    8     ssd      128         13.3   96890
# 4    Apple       MacBook Pro    8     ssd      256         13.3  112666
# ..     ...               ...  ...     ...      ...          ...     ...
# 162   Asus            A555LF    8     hdd     1024         15.6   39961
# 163   Asus     X555LA-XX172D    4     hdd      500         15.6   28489
# 164   Asus            X554LD    2     hdd      500         15.6   29199
# 165   Asus    X550LAV-XX771D    2     hdd      500         15.6   29990
# 166   Asus     X540LA-XX538T    4     hdd     1024         15.6   30899
#
#     processor_brand processor_model  clock_speed graphic_card_brand  \
# ...

# %%
 b_df.head(7)  # 앞부분 데이터부터 출력
# Out:
#                         model  ram hd_type  hd_size  screen_size   price  \
# brand
# Dell         Inspiron 15-3567    4     hdd     1024         15.6   40000
# Apple             MacBook Air    8     ssd      128         13.3   55499
# Apple             MacBook Air    8     ssd      256         13.3   71500
# Apple             MacBook Pro    8     ssd      128         13.3   96890
# Apple             MacBook Pro    8     ssd      256         13.3  112666
# Apple  MacBook Pro (TouchBar)   16     ssd      512         15.0  226000
# Apple  MacBook Pro (TouchBar)   16     ssd      512         13.3  158000
#
#       processor_brand processor_model  clock_speed graphic_card_brand  \
# brand
# Dell            intel              i5          2.5              intel
# Apple           intel              i5          1.8              intel
# Apple           intel              i5          1.8              intel
# Apple           intel              i5          2.3              intel
# ...

# %%
b_df.tail(3) # 끝부분 데이터부터 출력
# Out:
#                 model  ram hd_type  hd_size  screen_size  price  \
# brand
# Asus           X554LD    2     hdd      500         15.6  29199
# Asus   X550LAV-XX771D    2     hdd      500         15.6  29990
# Asus    X540LA-XX538T    4     hdd     1024         15.6  30899
#
#       processor_brand processor_model  clock_speed graphic_card_brand  \
# brand
# Asus            intel      i3 4th gen          1.9              intel
# Asus            intel      i3 4th gen          1.7              intel
# Asus            intel      i3 5th gen          2.0              intel
#
#        graphic_card_size       os  weight comments
# brand
# Asus                 1.0    linux     2.3      NaN
# Asus                 NaN    linux     2.5      NaN
# Asus                 NaN  windows     2.3      NaN

# %%
b_df.shape # 행/열 개수
# Out:
# (167, 14)

# %%
b_df.columns # 컬럼명
# Out:
# Index(['model', 'ram', 'hd_type', 'hd_size', 'screen_size', 'price',
#        'processor_brand', 'processor_model', 'clock_speed',
#        'graphic_card_brand', 'graphic_card_size', 'os', 'weight', 'comments'],
#       dtype='object')

# %%
b_df.info()  # 컬럼별 데이터 타입
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 167 entries, Dell to Asus
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   model               167 non-null    object
#  1   ram                 167 non-null    int64
#  2   hd_type             167 non-null    object
#  3   hd_size             167 non-null    int64
#  4   screen_size         167 non-null    float64
#  5   price               167 non-null    int64
#  6   processor_brand     167 non-null    object
#  7   processor_model     167 non-null    object
#  8   clock_speed         166 non-null    float64
#  9   graphic_card_brand  163 non-null    object
#  10  graphic_card_size   81 non-null     float64
#  11  os                  167 non-null    object
#  12  weight              160 non-null    float64
#  13  comments            55 non-null     object
# dtypes: float64(4), int64(3), object(7)
# memory usage: 19.6+ KB

# %%
b_df.describe()  #통계 정보
# Out:
#               ram     hd_size  screen_size          price  clock_speed  \
# count  167.000000   167.00000   167.000000     167.000000   166.000000
# mean     6.898204   768.91018    14.775210   64132.898204     2.321084
# std      3.787479   392.99080     1.376526   42797.674010     0.554187
# min      2.000000    32.00000    10.100000   13872.000000     1.100000
# 25%      4.000000   500.00000    14.000000   35457.500000     1.900000
# 50%      8.000000  1024.00000    15.600000   47990.000000     2.300000
# 75%      8.000000  1024.00000    15.600000   77494.500000     2.600000
# max     16.000000  2048.00000    17.600000  226000.000000     3.800000
#
#        graphic_card_size      weight
# count          81.000000  160.000000
# mean           52.160494    2.250812
# std           444.134142    0.648446
# min             1.000000    0.780000
# 25%             2.000000    1.900000
# 50%             2.000000    2.200000
# 75%             4.000000    2.600000
# ...

# %%
b_df.sort_values(by='price')  # 컬럼(price)를 기준으로 데이터프레임 정렬(오람차순)
# Out:
#                                 model  ram hd_type  hd_size  screen_size  \
# brand
# Acer                  Aspire SW3-016     2     ssd       32         10.1
# Acer          A315-31CDC UN.GNTSI.001    2     ssd      500         15.6
# Acer       Aspire ES-15 NX.GKYSI.010     4     hdd      500         15.6
# Acer         A315-31-P4CRUN.GNTSI.002    4     hdd      500         15.6
# Acer                  Aspire ES1-523     4     hdd     1024         15.6
# ...                               ...  ...     ...      ...          ...
# Microsoft      Surface Book CR9-00013    8     ssd      128         13.5
# Acer                      Predator 17   16     ssd      256         17.3
# Alienware          AW13R3-7000SLV-PUS    8     ssd      256         13.3
# Alienware                 15 Notebook   16     hdd     1024         15.6
# Apple          MacBook Pro (TouchBar)   16     ssd      512         15.0
#
#             price processor_brand processor_model  clock_speed  \
# brand
# ...

# %%
b_df.sort_values(by='price', ascending=False)  # 내림차순
# Out:
#                                 model  ram hd_type  hd_size  screen_size  \
# brand
# Apple          MacBook Pro (TouchBar)   16     ssd      512         15.0
# Alienware                 15 Notebook   16     hdd     1024         15.6
# Alienware          AW13R3-7000SLV-PUS    8     ssd      256         13.3
# Acer                      Predator 17   16     ssd      256         17.3
# Microsoft      Surface Book CR9-00013    8     ssd      128         13.5
# ...                               ...  ...     ...      ...          ...
# Acer                  Aspire ES1-523     4     hdd     1024         15.6
# Acer         A315-31-P4CRUN.GNTSI.002    4     hdd      500         15.6
# Acer       Aspire ES-15 NX.GKYSI.010     4     hdd      500         15.6
# Acer          A315-31CDC UN.GNTSI.001    2     ssd      500         15.6
# Acer                  Aspire SW3-016     2     ssd       32         10.1
#
#             price processor_brand processor_model  clock_speed  \
# brand
# ...

# %%
b_df
# Out:
#                   model  ram hd_type  hd_size  screen_size   price  \
# brand
# Dell   Inspiron 15-3567    4     hdd     1024         15.6   40000
# Apple       MacBook Air    8     ssd      128         13.3   55499
# Apple       MacBook Air    8     ssd      256         13.3   71500
# Apple       MacBook Pro    8     ssd      128         13.3   96890
# Apple       MacBook Pro    8     ssd      256         13.3  112666
# ...                 ...  ...     ...      ...          ...     ...
# Asus             A555LF    8     hdd     1024         15.6   39961
# Asus      X555LA-XX172D    4     hdd      500         15.6   28489
# Asus             X554LD    2     hdd      500         15.6   29199
# Asus     X550LAV-XX771D    2     hdd      500         15.6   29990
# Asus      X540LA-XX538T    4     hdd     1024         15.6   30899
#
#       processor_brand processor_model  clock_speed graphic_card_brand  \
# brand
# Dell            intel              i5          2.5              intel
# ...

# %%
b_df.sort_values(by='price', ascending=False, inplace=True)  # 정렬된 값을 원본에 저장
b_df
# Out:
#                                 model  ram hd_type  hd_size  screen_size  \
# brand
# Apple          MacBook Pro (TouchBar)   16     ssd      512         15.0
# Alienware                 15 Notebook   16     hdd     1024         15.6
# Alienware          AW13R3-7000SLV-PUS    8     ssd      256         13.3
# Acer                      Predator 17   16     ssd      256         17.3
# Microsoft      Surface Book CR9-00013    8     ssd      128         13.5
# ...                               ...  ...     ...      ...          ...
# Acer                  Aspire ES1-523     4     hdd     1024         15.6
# Acer         A315-31-P4CRUN.GNTSI.002    4     hdd      500         15.6
# Acer       Aspire ES-15 NX.GKYSI.010     4     hdd      500         15.6
# Acer          A315-31CDC UN.GNTSI.001    2     ssd      500         15.6
# Acer                  Aspire SW3-016     2     ssd       32         10.1
#
#             price processor_brand processor_model  clock_speed  \
# brand
# ...

# %%
b_df['brand'] #series 출력
# Out:
# 0       Dell
# 1      Apple
# 2      Apple
# 3      Apple
# 4      Apple
#        ...
# 162     Asus
# 163     Asus
# 164     Asus
# 165     Asus
# 166     Asus
# Name: brand, Length: 167, dtype: object

# %%
b_df['brand'].unique() #중복된 값 제거
# Out:
# array(['Dell', 'Apple', 'Acer', 'HP', 'Lenovo', 'Alienware', 'Microsoft',
#        'Asus'], dtype=object)

# %%
b_df['brand'].value_counts() #series별 종류 수
# Out:
# HP           55
# Acer         35
# Dell         31
# Lenovo       18
# Asus          9
# Apple         7
# Alienware     6
# Microsoft     6
# Name: brand, dtype: int64

# %%
b_df['brand'].describe() #series에 대한 요약 정보
# Out:
# count     167
# unique      8
# top        HP
# freq       55
# Name: brand, dtype: object
